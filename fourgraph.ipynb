# %%
#import the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#bring  in the data

# %%
dataset = pd.read_csv(r"C:\Users\USER\Desktop\dataframes\housing.csv")

# %%
#dataset

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dataset.shape
# Out:
# (20640, 10)

# %%
dataset.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
1#RELATIONSHIP
# Out:
# 1

# %%
pop=dataset['population']
value=dataset['median_house_value']

# %%
pop
# Out:
# 0         322.0
# 1        2401.0
# 2         496.0
# 3         558.0
# 4         565.0
#           ...
# 20635     845.0
# 20636     356.0
# 20637    1007.0
# 20638     741.0
# 20639    1387.0
# Name: population, Length: 20640, dtype: float64

# %%
income=dataset['median_income']

# %%
income
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: median_income, Length: 20640, dtype: float64

# %%
#the relattionship between income and population

# %%
plt.scatter(value,income,color='g',marker="*",alpha=.3)
plt.xlabel("house value")
plt.ylabel("relationship")
plt.show()

# %%
2#comparisons
# Out:
# 2

# %%
dataset.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
age=dataset["housing_median_age"]

# %%
plt.plot(age,pop)
plt.show()

# %%
plt.bar(age,pop)
plt.show()

# %%
3#distributions
# Out:
# 3

# %%
plt.hist(income,bins=20)
plt.show()

# %%
plt.boxplot(income)
plt.show()

# %%
#composition

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data=dataset["ocean_proximity"]

# %%
# Assuming `pop` is a pandas Series and `ocean` is a list
data = pop[:5]  # Extract the first 5 elements of the Series
ocean_labels = ['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND']

plt.pie(data, labels=ocean_labels, autopct='%1.1f%%')
plt.show()

# %%
data=dataset["ocean_proximity"]
