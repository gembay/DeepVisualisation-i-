# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
ds = pd.read_csv("housing.csv")

# %%
ds.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
ds.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
ds.nunique()
# Out:
# longitude               844
# latitude                861
# housing_median_age       52
# total_rooms            5911
# total_bedrooms         1923
# population             3879
# households             1809
# median_income         12825
# median_house_value     3833
# ocean_proximity           5
# dtype: int64

# %%
ds.shape
# Out:
# (20640, 10)

# %%
ds.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
ds.dropna(inplace=True)

# %%
ds.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#RELATIONSHIP GRAPHS

# %%
#RELATIONSHIP BETWEEEN AGE AND POPULATION

# %%
plt.scatter(ds['housing_median_age'],ds['population'],marker="*",alpha=0.5)
plt.title("#RELATIONSHIP BETWEEEN AGE AND POPULATION")
plt.xlabel("age")
plt.ylabel("population")
plt.show()

# %%
#RELATIONSHIP BETWEEEN AGE AND TOTALROOMS

# %%
plt.scatter(ds['housing_median_age'],ds['total_rooms'],marker="*",alpha=0.5)
plt.title("RELATIONSHIP BETWEEEN AGE AND ROOMS")
plt.xlabel("age")
plt.ylabel("rooms")
plt.show()

# %%
#RELATIONSHIP BETWEEEN AGE AND BEDROOOMS

# %%
plt.scatter(ds['housing_median_age'],ds['total_bedrooms'],marker="*",alpha=0.5)
plt.title("RELATIONSHIP BETWEEEN AGE AND BEDROOMS")
plt.xlabel("age")
plt.ylabel("bedrooms")
plt.show()

# %%
#RELATIONSHIP BETWEEEN AGE AND INCOME

# %%
plt.scatter(ds['housing_median_age'],ds['median_income'],marker="*",alpha=0.5)
plt.title("RELATIONSHIP BETWEEEN AGE AND INCOME")
plt.xlabel("age")
plt.ylabel("income")
plt.show()

# %%
#RELATIONSHIP BETWEEEN AGE AND VALUE

# %%
plt.scatter(ds['housing_median_age'],ds['median_house_value'],marker="*",alpha=0.5)
plt.title("RELATIONSHIP BETWEEEN AGE AND VALUE")
plt.xlabel("age")
plt.ylabel("value")
plt.show()

# %%
#RELATIONSHIP BETWEEEN POPULATION AND VALUE

# %%
plt.scatter(ds['population'],ds['median_house_value'],marker="*",alpha=0.5)
plt.title("RELATIONSHIP BETWEEEN AGE AND VALUE")
plt.xlabel("population")
plt.ylabel("value")
plt.show()

# %%
#RELATIONSHIP BETWEEEN POPULATION AND TOTAL ROOMS

# %%
plt.scatter(ds['population'],ds['total_rooms'],marker="*",alpha=0.5)
plt.title("RELATIONSHIP BETWEEEN POPULATION AND BEDROOMS")
plt.xlabel("POPULATION")
plt.ylabel("bedrooms")
plt.show()

# %%
#RELATIONSHIP BETWEEEN POPULATION AND BEDROOMS

# %%
plt.scatter(ds['population'],ds['total_bedrooms'],marker="*",alpha=0.5)
plt.title("RELATIONSHIP BETWEEEN POPULATION AND BEDROOMS")
plt.xlabel("POPULATION")
plt.ylabel("rooms")
plt.show()

# %%
#RELATIONSHIP BETWEEEN POPULATION AND INCOME

# %%
plt.scatter(ds['population'],ds['median_income'],marker="*",alpha=0.5)
plt.title("RELATIONSHIP BETWEEEN POPULATION AND income")
plt.xlabel("POPULATION")
plt.ylabel("incoem")
plt.show()

# %%
#COMPARISONS

# %%
#COMPARING OCEAN PROVIMTY AND POPULATION

# %%
plt.bar(ds['ocean_proximity'],ds['population'])
plt.title("COMPARISON BETWEEEN POPULATION ANDOCEAN_PROX")
plt.xlabel("ocean")
plt.ylabel("population")
plt.show()

# %%
#COMPARING OCEAN PROVIMTY AND INCOME

# %%
plt.bar(ds['ocean_proximity'],ds['median_income'])
plt.title("COMPARISON BETWEEEN OCEAN AND INCOME")
plt.xlabel("ocean")
plt.ylabel("income")
plt.show()

# %%
#COMPARING OCEAN PROVIMTY AND HOUSEVALUE

# %%
plt.bar(ds['ocean_proximity'],ds['median_house_value'])
plt.title("COMPARISON BETWEEEN ocean prox and house value")
plt.xlabel("ocean")
plt.ylabel("value")
plt.show()

# %%
#COMPARING OCEAN PROVIMTY AND Age

# %%
plt.bar(ds['ocean_proximity'],ds['housing_median_age'])
plt.title("COMPARISON BETWEEEN ocean prox and house value")
plt.xlabel("ocean")
plt.ylabel(" age")
plt.show()

# %%
#DISTIBUTION

# %%
#A DISTRIBUTED POPULATION GRAPH

# %%
plt.hist(ds['population'])
plt.title("DISTRIBUTION  OF POPULATION")
plt.xlabel("FREQ")
plt.ylabel(" POPULATION")
plt.show()

# %%
#A DISTRIBUTED AGE GRAPH

# %%
plt.hist(ds['housing_median_age'])
plt.title("DISTRIBUTION  OF HOUSEAGE")
plt.xlabel("FREQ")
plt.ylabel(" AGE")
plt.show()

# %%
#A DISTRIBUTED INCOME GRAPH

# %%
plt.hist(ds['median_income'])
plt.title("DISTRIBUTION  OF INCOME")
plt.xlabel("FREQ")
plt.ylabel(" INCOME")
plt.show()

# %%
#A DISTRIBUTED HOUSEAGE GRAPH

# %%
plt.hist(ds['total_rooms'])
plt.title("DISTRIBUTION  OF totalrooms")
plt.xlabel("FREQ")
plt.ylabel(" rooms")
plt.show()

# %%
#A DISTRIBUTED house value GRAPH

# %%
plt.hist(ds['median_house_value'])
plt.title("DISTRIBUTION  OF VALUE")
plt.ylabel("FREQ")
plt.xlabel(" $VALUE")
plt.show()

# %%
#A DISTRIBUTED house value GRAPH

# %%
plt.hist(ds['ocean_proximity'],bins=5)
plt.title("DISTRIBUTION  OF OCEAN PROX")
plt.ylabel("FREQ")
plt.xlabel(" OCEAN")
plt.show()

# %%
#COMPOSITION

# %%
#COMPOSITION OF OCEAN PROX
ds['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
category_counts = ds['ocean_proximity'].value_counts()
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.title("Distribution of Ocean Proximity")
plt.show()
